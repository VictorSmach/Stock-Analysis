# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorSmach/Stock-Analysis/blob/main/Colab's_New_Code_Editor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colab's New Code Editor
#
# Colab is moving to a new code editor which includes:
# * Richer completions
# * Additional keybinding options
# * Improved accessibility

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import dtatetime as dt
from pandas_datareader import data as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-1ea1bbc1c6b0> in <module>()
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import yfinance as yf
#       4 import dtatetime as dt
#       5 from pandas_datareader import data as pd
#
# ModuleNotFoundError: No module named 'yfinance'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install scipy

# %%
pip install yfinance
# Out:
# ...
#      |████████████████████████████████| 6.3 MB 40.5 MB/s
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.63-py2.py3-none-any.whl size=23919 sha256=d8172dcf52f3abfe85309eceb28d43cf78c068120fda0110d3c974f764af0e9b
#   Stored in directory: /root/.cache/pip/wheels/fe/87/8b/7ec24486e001d3926537f5f7801f57a74d181be25b11157983
# Successfully built yfinance
# ...
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import datetime as dt
from pandas_datareader import data as pdr

# %%
yf.pdr_override()

stock = input("Ënter the stock ticker symbol:")
# Out:
# Ënter the stock ticker symbol:NIO

# %%
startyear = 2017
startmonth = 1
startday = 1

start = dt.datetime(startyear, startmonth, startday)
now = dt.datetime.now()

df = pdr.get_data_yahoo(stock, start, now)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2018-09-12   6.000000   6.930000   5.350000   6.600000   6.600000   66849000
# 2018-09-13   6.620000  12.690000   6.520000  11.600000  11.600000  158346500
# 2018-09-14  12.660000  13.800000   9.220000   9.900000   9.900000  172473600
# 2018-09-17   9.610000   9.750000   8.500000   8.500000   8.500000   56323900
# 2018-09-18   8.730000   9.100000   7.670000   7.680000   7.680000   41827600
# ...               ...        ...        ...        ...        ...        ...
# 2021-07-19  41.490002  43.669998  40.480000  43.349998  43.349998   65290100
# 2021-07-20  43.599998  44.410000  42.430000  44.169998  44.169998   37932300
# 2021-07-21  44.099998  47.380001  44.000000  46.770000  46.770000   59851700
# 2021-07-22  46.959999  47.380001  45.470001  46.070000  46.070000   38936400
# 2021-07-23  43.669998  44.500000  42.500000  43.990002  43.990002   49472400
#
# [721 rows x 6 columns]

# %%
ma = 50

smaString = "Sma_" + str(ma) 

df[smaString] = df.iloc[:,4].rolling(window=ma).mean()

print(df)
# Out:
#                  Open       High        Low  ...  Adj Close     Volume   Sma_50
# Date                                         ...
# 2018-09-12   6.000000   6.930000   5.350000  ...   6.600000   66849000      NaN
# 2018-09-13   6.620000  12.690000   6.520000  ...  11.600000  158346500      NaN
# 2018-09-14  12.660000  13.800000   9.220000  ...   9.900000  172473600      NaN
# 2018-09-17   9.610000   9.750000   8.500000  ...   8.500000   56323900      NaN
# 2018-09-18   8.730000   9.100000   7.670000  ...   7.680000   41827600      NaN
# ...               ...        ...        ...  ...        ...        ...      ...
# 2021-07-19  41.490002  43.669998  40.480000  ...  43.349998   65290100  42.1948
# 2021-07-20  43.599998  44.410000  42.430000  ...  44.169998   37932300  42.3394
# 2021-07-21  44.099998  47.380001  44.000000  ...  46.770000   59851700  42.5882
# 2021-07-22  46.959999  47.380001  45.470001  ...  46.070000   38936400  42.8122
# ...

# %%
df = df.iloc[ma:]
df
# Out:
#                  Open       High        Low  ...  Adj Close    Volume   Sma_50
# Date                                         ...
# 2018-11-21   7.900000   8.050000   7.630000  ...   7.710000  13993600   7.2324
# 2018-11-23   7.680000   7.700000   7.410000  ...   7.460000   8119700   7.1496
# 2018-11-26   7.610000   7.630000   7.160000  ...   7.370000  12164900   7.0990
# 2018-11-27   7.300000   7.700000   7.230000  ...   7.480000   9084900   7.0786
# 2018-11-28   7.600000   8.150000   7.600000  ...   8.120000  22096900   7.0874
# ...               ...        ...        ...  ...        ...       ...      ...
# 2021-07-19  41.490002  43.669998  40.480000  ...  43.349998  65290100  42.1948
# 2021-07-20  43.599998  44.410000  42.430000  ...  44.169998  37932300  42.3394
# 2021-07-21  44.099998  47.380001  44.000000  ...  46.770000  59851700  42.5882
# 2021-07-22  46.959999  47.380001  45.470001  ...  46.070000  38936400  42.8122
# ...

# %%
numH = 0
numC = 0
for i in df.index:
  if(df["Adj Close"][i]>df[smaString][i]):
    print("The close is higher")
    numH+=1
  else:
    print("The close is lower")
    numC+=1

print(str(numH))
print(str(numC))
# Out:
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is lower
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is higher
# ...
